# %%
import numpy as np

# %%
text = """
. . . . . . . . . . . . . . . . . . . . . . . . . .
. . . . . . A . . . . . . . . . . . . . . . . . . .
. . . . . . L . . . . . . G . . . . . . . . . . . .
. P . . . . K . . . . . . L . . . . # . . . . . . .
. R . . . . A . . . C H # O R O P L A S T . . . . .
. O . . W . L . . . . # . B . . . . L . . . . . . .
. P Y # # M # D . . . X . # . . . . E . . . . . . .
. A . . T . . E . . . A . . . . . . N . . T . . . .
. # . . T . . # . . . G . W . . . A C U T # . . . .
. E . . . # Y T H A G O R A S . . . E . . R . . . .
. . . . . L . E . . . N . T . . . . . . . M . . . .
. . . # U A D R A N T . . # . . . . . . . I . . . .
. . . . . # . I . . . . . R . . . . . . . # . . . .
. . . . . M . U . . . . . . . L I G H T S # B E R .
. . . . M A M M # T H . . . . . . . . . . L . . . .
. . . . . . . . . . . . . . . . . . . . . . . . . ."""
text
# Out:
# '\n. . . . . . . . . . . . . . . . . . . . . . . . . .\n. . . . . . A . . . . . . . . . . . . . . . . . . .\n. . . . . . L . . . . . . G . . . . . . . . . . . .\n. P . . . . K . . . . . . L . . . . # . . . . . . .\n. R . . . . A . . . C H # O R O P L A S T . . . . .\n. O . . W . L . . . . # . B . . . . L . . . . . . .\n. P Y # # M # D . . . X . # . . . . E . . . . . . .\n. A . . T . . E . . . A . . . . . . N . . T . . . .\n. # . . T . . # . . . G . W . . . A C U T # . . . .\n. E . . . # Y T H A G O R A S . . . E . . R . . . .\n. . . . . L . E . . . N . T . . . . . . . M . . . .\n. . . # U A D R A N T . . # . . . . . . . I . . . .\n. . . . . # . I . . . . . R . . . . . . . # . . . .\n. . . . . M . U . . . . . . . L I G H T S # B E R .\n. . . . M A M M # T H . . . . . . . . . . L . . . .\n. . . . . . . . . . . . . . . . . . . . . . . . . .'

# %%
arr = []

for i in text.split("\n"):
  arr.append(i.split(" "))

arr = arr[1:]
print(arr)
# Out:
# [['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', 'A', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', 'L', '.', '.', '.', '.', '.', '.', 'G', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', 'P', '.', '.', '.', '.', 'K', '.', '.', '.', '.', '.', '.', 'L', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.'], ['.', 'R', '.', '.', '.', '.', 'A', '.', '.', '.', 'C', 'H', '#', 'O', 'R', 'O', 'P', 'L', 'A', 'S', 'T', '.', '.', '.', '.', '.'], ['.', 'O', '.', '.', 'W', '.', 'L', '.', '.', '.', '.', '#', '.', 'B', '.', '.', '.', '.', 'L', '.', '.', '.', '.', '.', '.', '.'], ['.', 'P', 'Y', '#', '#', 'M', '#', 'D', '.', '.', '.', 'X', '.', '#', '.', '.', '.', '.', 'E', '.', '.', '.', '.', '.', '.', '.'], ['.', 'A', '.', '.', 'T', '.', '.', 'E', '.', '.', '.', 'A', '.', '.', '.
# ...

# %%
arr = np.array(arr)
arr
# Out:
# array([['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.',
#         '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#        ['.', '.', '.', '.', '.', '.', 'A', '.', '.', '.', '.', '.', '.',
#         '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#        ['.', '.', '.', '.', '.', '.', 'L', '.', '.', '.', '.', '.', '.',
#         'G', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#        ['.', 'P', '.', '.', '.', '.', 'K', '.', '.', '.', '.', '.', '.',
#         'L', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.'],
#        ['.', 'R', '.', '.', '.', '.', 'A', '.', '.', '.', 'C', 'H', '#',
#         'O', 'R', 'O', 'P', 'L', 'A', 'S', 'T', '.', '.', '.', '.', '.'],
#        ['.', 'O', '.', '.', 'W', '.', 'L', '.', '.', '.', '.', '#', '.',
#         'B', '.', '.', '.', '.', 'L', '.', '.', '.', '.', '.', '.', '.'],
#        ['.', 'P', 'Y', '#', '#', 'M', '#', 'D', '.', '.', '.', 'X', '.',
# ...

# %%
print(text)
# Out:
# . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . A . . . . . . . . . . . . . . . . . . .
# . . . . . . L . . . . . . G . . . . . . . . . . . .
# . P . . . . K . . . . . . L . . . . # . . . . . . .
# . R . . . . A . . . C H # O R O P L A S T . . . . .
# . O . . W . L . . . . # . B . . . . L . . . . . . .
# . P Y # # M # D . . . X . # . . . . E . . . . . . .
# . A . . T . . E . . . A . . . . . . N . . T . . . .
# . # . . T . . # . . . G . W . . . A C U T # . . . .
# . E . . . # Y T H A G O R A S . . . E . . R . . . .
# . . . . . L . E . . . N . T . . . . . . . M . . . .
# . . . # U A D R A N T . . # . . . . . . . I . . . .
# . . . . . # . I . . . . . R . . . . . . . # . . . .
# . . . . . M . U . . . . . . . L I G H T S # B E R .
# . . . . M A M M # T H . . . . . . . . . . L . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . .

# %%
arr[np.where(arr != '.')]
# Out:
# array(['A', 'L', 'G', 'P', 'K', 'L', '#', 'R', 'A', 'C', 'H', '#', 'O',
#        'R', 'O', 'P', 'L', 'A', 'S', 'T', 'O', 'W', 'L', '#', 'B', 'L',
#        'P', 'Y', '#', '#', 'M', '#', 'D', 'X', '#', 'E', 'A', 'T', 'E',
#        'A', 'N', 'T', '#', 'T', '#', 'G', 'W', 'A', 'C', 'U', 'T', '#',
#        'E', '#', 'Y', 'T', 'H', 'A', 'G', 'O', 'R', 'A', 'S', 'E', 'R',
#        'L', 'E', 'N', 'T', 'M', '#', 'U', 'A', 'D', 'R', 'A', 'N', 'T',
#        '#', 'I', '#', 'I', 'R', '#', 'M', 'U', 'L', 'I', 'G', 'H', 'T',
#        'S', '#', 'B', 'E', 'R', 'M', 'A', 'M', 'M', '#', 'T', 'H', 'L'],
#       dtype='<U1')

# %%
np.where(arr[np.where(arr != '.')] == "#")[0]
# Out:
# array([  6,  11,  23,  28,  29,  31,  34,  42,  44,  51,  53,  70,  78,
#         80,  83,  92, 100], dtype=int64)

# %%
letterArr = np.array(["l","e","v","e","n","s","q","u","a","r","e","p","i","a","n","o","e"])

# %%
for i in range(len(letterArr)):
  letterArr[i] = letterArr[i].upper()

# %%
np.random.shuffle(letterArr)
letterArr
# Out:
# array(['E', 'E', 'R', 'E', 'I', 'Q', 'A', 'A', 'S', 'P', 'E', 'V', 'L',
#        'O', 'N', 'N', 'U'], dtype='<U1')
